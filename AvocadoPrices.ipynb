# %% [markdown]
# <a href="https://colab.research.google.com/github/SilaTan/Avocado-Prices/blob/master/AvocadoPrices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("/content/drive/MyDrive/CSV UZANTILARIM/avocado.csv")
data
# Out:
#        Unnamed: 0        Date  ...  year            region
# 0               0  2015-12-27  ...  2015            Albany
# 1               1  2015-12-20  ...  2015            Albany
# 2               2  2015-12-13  ...  2015            Albany
# 3               3  2015-12-06  ...  2015            Albany
# 4               4  2015-11-29  ...  2015            Albany
# ...           ...         ...  ...   ...               ...
# 18244           7  2018-02-04  ...  2018  WestTexNewMexico
# 18245           8  2018-01-28  ...  2018  WestTexNewMexico
# 18246           9  2018-01-21  ...  2018  WestTexNewMexico
# 18247          10  2018-01-14  ...  2018  WestTexNewMexico
# 18248          11  2018-01-07  ...  2018  WestTexNewMexico
#
# [18249 rows x 14 columns]

# %%
data.drop(data.columns[0], axis=1, inplace=True)

# %%
data
# Out:
#              Date  AveragePrice  ...  year            region
# 0      2015-12-27          1.33  ...  2015            Albany
# 1      2015-12-20          1.35  ...  2015            Albany
# 2      2015-12-13          0.93  ...  2015            Albany
# 3      2015-12-06          1.08  ...  2015            Albany
# 4      2015-11-29          1.28  ...  2015            Albany
# ...           ...           ...  ...   ...               ...
# 18244  2018-02-04          1.63  ...  2018  WestTexNewMexico
# 18245  2018-01-28          1.71  ...  2018  WestTexNewMexico
# 18246  2018-01-21          1.87  ...  2018  WestTexNewMexico
# 18247  2018-01-14          1.93  ...  2018  WestTexNewMexico
# 18248  2018-01-07          1.62  ...  2018  WestTexNewMexico
#
# [18249 rows x 13 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  object
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 1.8+ MB

# %%
data.isna().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
def get_uniques(df, columns):
    return {column: list(df[column].unique()) for column in columns}

# %%
categorical_columns = ['region', 'Date', 'type']

get_uniques(data, categorical_columns)
# Out:
# {'Date': ['2015-12-27',
#   '2015-12-20',
#   '2015-12-13',
#   '2015-12-06',
#   '2015-11-29',
#   '2015-11-22',
#   '2015-11-15',
#   '2015-11-08',
#   '2015-11-01',
#   '2015-10-25',
#   '2015-10-18',
#   '2015-10-11',
#   '2015-10-04',
#   '2015-09-27',
#   '2015-09-20',
#   '2015-09-13',
#   '2015-09-06',
#   '2015-08-30',
#   '2015-08-23',
#   '2015-08-16',
#   '2015-08-09',
#   '2015-08-02',
#   '2015-07-26',
#   '2015-07-19',
#   '2015-07-12',
#   '2015-07-05',
#   '2015-06-28',
#   '2015-06-21',
#   '2015-06-14',
#   '2015-06-07',
#   '2015-05-31',
#   '2015-05-24',
#   '2015-05-17',
#   '2015-05-10',
#   '2015-05-03',
#   '2015-04-26',
#   '2015-04-19',
#   '2015-04-12',
#   '2015-04-05',
#   '2015-03-29',
#   '2015-03-22',
#   '2015-03-15',
#   '2015-03-08',
#   '2015-03-01',
#   '2015-02-22',
#   '2015-02-15',
#   '2015-02-08',
#   '2015-02-01',
#   '2015-01-25',
#   '2015-01-18',
#   '2015-01-11',
#   '2015-01-04',
#   '2016-12-25',
#   '2016-12-18',
#   '2016-12-11',
# ...

# %%
ordinal_features = ['Date']

nominal_features = ['region']

target_column = 'type'

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
def ordinal_encode(df, column, ordering):
    df = df.copy()
    df[column] = df[column].apply(lambda x: ordering.index(x))
    return df

# %%
date_ordering = sorted(data['Date'].unique())
date_ordering
# Out:
# ['2015-01-04',
#  '2015-01-11',
#  '2015-01-18',
#  '2015-01-25',
#  '2015-02-01',
#  '2015-02-08',
#  '2015-02-15',
#  '2015-02-22',
#  '2015-03-01',
#  '2015-03-08',
#  '2015-03-15',
#  '2015-03-22',
#  '2015-03-29',
#  '2015-04-05',
#  '2015-04-12',
#  '2015-04-19',
#  '2015-04-26',
#  '2015-05-03',
#  '2015-05-10',
#  '2015-05-17',
#  '2015-05-24',
#  '2015-05-31',
#  '2015-06-07',
#  '2015-06-14',
#  '2015-06-21',
#  '2015-06-28',
#  '2015-07-05',
#  '2015-07-12',
#  '2015-07-19',
#  '2015-07-26',
#  '2015-08-02',
#  '2015-08-09',
#  '2015-08-16',
#  '2015-08-23',
#  '2015-08-30',
#  '2015-09-06',
#  '2015-09-13',
#  '2015-09-20',
#  '2015-09-27',
#  '2015-10-04',
#  '2015-10-11',
#  '2015-10-18',
#  '2015-10-25',
#  '2015-11-01',
#  '2015-11-08',
#  '2015-11-15',
#  '2015-11-22',
#  '2015-11-29',
#  '2015-12-06',
#  '2015-12-13',
#  '2015-12-20',
#  '2015-12-27',
#  '2016-01-03',
#  '2016-01-10',
#  '2016-01-17',
#  '2016-01-24',
#  '2016-01-31',
#  '2016-02-07',
# ...

# %%
data = ordinal_encode(data, 'Date', date_ordering)

# %%
def onehot_encode(df, column):
    df = df.copy()
    dummies = pd.get_dummies(df[column])
    df = pd.concat([df, dummies], axis=1)
    df.drop(column, axis=1, inplace=True)
    return df

# %%
data = onehot_encode(data, 'region')

# %%
data
# Out:
#        Date  AveragePrice  Total Volume  ...  TotalUS  West  WestTexNewMexico
# 0        51          1.33      64236.62  ...        0     0                 0
# 1        50          1.35      54876.98  ...        0     0                 0
# 2        49          0.93     118220.22  ...        0     0                 0
# 3        48          1.08      78992.15  ...        0     0                 0
# 4        47          1.28      51039.60  ...        0     0                 0
# ...     ...           ...           ...  ...      ...   ...               ...
# 18244   161          1.63      17074.83  ...        0     0                 1
# 18245   160          1.71      13888.04  ...        0     0                 1
# 18246   159          1.87      13766.76  ...        0     0                 1
# 18247   158          1.93      16205.22  ...        0     0                 1
# 18248   157          1.62      17489.58  ...        0     0                 1
#
# [18249 rows x 66 columns]

# %%
label_encoder = LabelEncoder()
data[target_column] = label_encoder.fit_transform(data[target_column])
data
# Out:
#        Date  AveragePrice  Total Volume  ...  TotalUS  West  WestTexNewMexico
# 0        51          1.33      64236.62  ...        0     0                 0
# 1        50          1.35      54876.98  ...        0     0                 0
# 2        49          0.93     118220.22  ...        0     0                 0
# 3        48          1.08      78992.15  ...        0     0                 0
# 4        47          1.28      51039.60  ...        0     0                 0
# ...     ...           ...           ...  ...      ...   ...               ...
# 18244   161          1.63      17074.83  ...        0     0                 1
# 18245   160          1.71      13888.04  ...        0     0                 1
# 18246   159          1.87      13766.76  ...        0     0                 1
# 18247   158          1.93      16205.22  ...        0     0                 1
# 18248   157          1.62      17489.58  ...        0     0                 1
#
# [18249 rows x 66 columns]

# %%
y = data[target_column]
X = data.drop(target_column, axis=1)

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)
X
# Out:
# array([[-0.67635986, -0.18868864, -0.22771641, ..., -0.13737207,
#         -0.13737207, -0.13674962],
#        [-0.69685742, -0.13901962, -0.23042664, ..., -0.13737207,
#         -0.13737207, -0.13674962],
#        [-0.71735497, -1.18206895, -0.21208462, ..., -0.13737207,
#         -0.13737207, -0.13674962],
#        ...,
#        [ 1.53737632,  1.15237477, -0.24233073, ..., -0.13737207,
#         -0.13737207,  7.31263474],
#        [ 1.51687877,  1.30138182, -0.24162464, ..., -0.13737207,
#         -0.13737207,  7.31263474],
#        [ 1.49638121,  0.53151208, -0.24125273, ..., -0.13737207,
#         -0.13737207,  7.31263474]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7)

# %%
import tensorflow as tf

inputs = tf.keras.Input(65,)
x = tf.keras.layers.Dense(64, activation='relu')(inputs)
x = tf.keras.layers.Dense(64, activation='relu')(x)
outputs = tf.keras.layers.Dense(1, activation='sigmoid')(x)

model = tf.keras.Model(inputs=inputs, outputs=outputs)


model.compile(
    optimizer='adam',
    loss='mse',
    metrics=['accuracy']
)

batch_size = 64
epochs = 73

history = model.fit(
    X_train,
    y_train,
    validation_split=0.2,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=[tf.keras.callbacks.ReduceLROnPlateau()],
    verbose=0
)

# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(14, 10))

epochs_range = range(1, epochs + 1)
train_loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(epochs_range, train_loss, label="Training Loss")
plt.plot(epochs_range, val_loss, label="Validation Loss")

plt.title("Training and Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 172/172 [==============================] - 1s 3ms/step - loss: 3.8337e-04 - accuracy: 1.0000
# [0.0003833672672044486, 1.0]
